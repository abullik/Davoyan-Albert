# %%
import pandas as pd

# %% [markdown]
# Функция создает таблицу с предложениями и граммемами всех слов в предложении. Та же функция описана в файле prepframe. Эта работает на 2 минуты дольше, но не гавнокод.

# %%
def prepfinder(word, table, filename):
    
    import re, csv
    from time import time
    start = time()
    
    cases = {'n': 'nominative', 'g': 'genitive', 'd': 'dative', 'a': 'accusative', 'v': 'vocative', 'l': 'locative', 
             'i': 'instrumental'}
    
    prep_counter = dict()
    noun_counter = dict()
    cases_counter = dict()
    
    def crawler(table, index, direction):
        tags = [''] * 10
        tokens = [''] * 10
        words = 0
        step = direction

        while table['gramm'].loc[index + step] != 'SENT' and words < 10 and 0 <= index + step < len(table):
            if re.search('\w', table['token'].loc[index + step]):
                if table['POS'].loc[index + step] in 'NSM':
                    tags[words] = table['gramm'].loc[index + step]
                    tokens[words] = table['token'].loc[index + step]
                    current_word = table['lemma'].loc[index + step]
                    current_gramm = table['gramm'].loc[index + step]
                    if table['POS'].loc[index + step] == 'N' and len(current_gramm) >= 5:
                        noun_counter[current_word] = noun_counter.get(current_word, 0) + 1
                        cases_counter[current_gramm[4]] = cases_counter.get(current_gramm[4], 0) + 1
                    elif table['POS'].loc[index + step] == 'S':
                        prep_counter[current_word] = prep_counter.get(current_word, 0) + 1
                else:
                    tags[words] = '-'
                    tokens[words] = '-'
                words += 1
            step += direction
        return (tags[::direction], tokens[::direction])
    
    with open(filename, 'a', encoding='utf-8') as infotable:
        writer = csv.writer(infotable, quoting=csv.QUOTE_NONE, escapechar='', quotechar='', delimiter='\t', lineterminator='\n')
        col_names = ['L10','L9','L8','L7','L6','L5','L4','L3','L2','L1','Verb','R1','R2','R3','R4','R5','R6','R7','R8','R9','R10']
        writer.writerow(col_names)
        infotable.flush()
        for index, row in table.iterrows():
            if row['lemma'] == word: 
                left = crawler(table, index, -1)
                right = crawler(table, index, 1)
        
                tags = left[0] + ['V'] + right[0]
                tokens = left[1] + [word] + right[1]
                
                writer.writerow(tags)
                writer.writerow(tokens)
                writer.writerow(' ')
                infotable.flush()
                
    print('Extraction time: {}'.format((time() - start) / 60))
    return (prep_counter, noun_counter, cases_counter)

# %%
document = pd.read_csv('.\corpora\corpus-i-part1.txt', delimiter='\t', header = 0)

# %%
(preps, nouns, cases) = prepfinder('любить', document, 'prepslubit.csv')
# Out:
# Extraction time: 53.48820296923319

# %%
preps
# Out:
# {'без': 13,
#  'благодаря': 1,
#  'в': 301,
#  'включая': 1,
#  'вместо': 1,
#  'вне': 1,
#  'во': 17,
#  'вокруг': 1,
#  'вроде': 1,
#  'для': 24,
#  'до': 24,
#  'за': 50,
#  'из': 40,
#  'из-за': 4,
#  'из-под': 1,
#  'к': 35,
#  'ко': 1,
#  'кроме': 3,
#  'на': 155,
#  'над': 4,
#  'насчет': 1,
#  'о': 48,
#  'об': 6,
#  'обо': 1,
#  'около': 2,
#  'от': 32,
#  'перед': 5,
#  'по': 64,
#  'под': 8,
#  'помимо': 1,
#  'после': 8,
#  'посреди': 1,
#  'прежде': 1,
#  'при': 13,
#  'про': 7,
#  'против': 1,
#  'ради': 2,
#  'с': 122,
#  'со': 15,
#  'среди': 3,
#  'у': 62,
#  'через': 4}

# %%
nouns
# Out:
# {'повтор': 1,
#  'рождение': 2,
#  'черномырдин': 1,
#  'креативность': 1,
#  'парашют': 1,
#  'вася': 1,
#  'дедушка': 2,
#  'мир': 10,
#  'яковлевич': 1,
#  'исполнитель': 1,
#  'несправедливость': 1,
#  'полиграф': 1,
#  'изюм': 1,
#  'занятие': 2,
#  'гоген': 1,
#  'любитель': 1,
#  'интерфакс': 1,
#  'врач-невропатолог': 2,
#  'сестра': 3,
#  'калининград': 1,
#  'понятие': 1,
#  'дорожка': 2,
#  'леопольд': 1,
#  'наука': 5,
#  'представление': 1,
#  'мстиславовна': 1,
#  'основное': 1,
#  'фланг': 1,
#  'раздражение': 1,
#  'месяц': 3,
#  'казанова': 1,
#  'клиент': 1,
#  'профессия': 7,
#  'жданов': 1,
#  'сало': 1,
#  'перепад': 1,
#  'пролетариат': 2,
#  'дизайнер': 1,
#  'сцена': 4,
#  'суд': 1,
#  'банк': 3,
#  'обаяние': 1,
#  'петраков': 1,
#  'галина': 1,
#  'супруга': 2,
#  'мальчик': 3,
#  'атмосфера': 2,
#  'факт': 3,
#  'ветеран': 1,
#  'вдохновенье': 1,
#  'говорок': 1,
#  'излишество': 1,
#  'рука': 6,
#  'анастасия': 2,
#  'кафе': 1,
#  'поколение': 4,
#  'заводчанин': 1,
#  'плодоношение': 1,
#  'иммигрант': 1,
#  'фильм': 13,
#  'брат-близнец': 1,
#  'мачеха': 1,
#  'беспорядок': 1,
#  'vesti': 1,
#  'век': 3,
#  'скорость': 2,
#  'подарок': 6,
#  'форма': 3,
#  'наркотик': 1,
#  'шоколад': 1,
#  'шанс': 2,
#  'крайность': 3,
#  'гамбургер': 1,
#  'предложение': 2,
#  'михайлов': 1,
#  'душ': 1,
#  'заключенный': 1,
#  'яркость': 1,
#  'дурак': 2,
#  'природа': 10,
#  'ресторанчик': 1,
#  'ирландец': 1,
#  'нелли': 1,
#  'слог': 1,
#  'зайчик': 1,
#  'время': 32,
#  'цифра': 2,
#  'франция': 1,
#  'преферанс': 1,
#  'самозабвение': 2,
#  'схватка': 1,
#  'нестабильность': 1,
#  'печка': 1,
#  'изречение': 1,
#  'страна': 16,
#  'скандар': 1,
#  'узбечок': 1,
#  'албанц': 1,
#  'блокирование': 1,
#  'утро': 1,
#  'начальство': 1,
#  'вампир': 2,
#  'смит': 1,
#  'прокуратура': 1,
#  'роб-грийе': 1,
#  'ковалев': 1,
#  'бахти': 1,
#  'правление': 2,
#  'хокка': 1,
#  'выбор': 1,
#  'агния': 1,
#  'норвегия': 1,
#  'успокоение': 1,
#  'форум': 1,
#  'ия': 1,
#  'зайцев': 1,
#  'луиша': 1,
#  'щелканье': 1,
#  'генри': 1,
#  'премьер': 2,
#  'изумруд': 1,
#  'карелия': 1,
#  'одежда': 1,
#  'сереженька': 1,
#  'корень': 2,
#  'творчество': 1,
#  'красота': 8,
#  'эмми': 1,
#  'фантастика': 1,
#  'шумиха': 1,
#  'клетка': 1,
#  'олигарх': 1,
#  'станислав': 1,
#  'плавание': 2,
#  'автоспорт': 1,
#  'триединство': 1,
#  'француз': 1,
#  'забота': 4,
#  'видеоигра': 1,
#  'неповторимость': 1,
#  'мозер': 1,
#  'ирина': 1,
#  'волос': 1,
#  'гость': 3,
#  'робертс': 1,
#  'кольцо': 1,
#  'мундир': 1,
#  'доктор': 1,
#  'директор': 5,
#  'тема': 2,
#  'зоя': 1,
#  'кинг': 1,
#  'желание': 2,
#  'федерация': 1,
#  'начальник': 4,
#  'подглядывание': 1,
#  'угода': 1,
#  'район': 3,
#  'история': 9,
#  'фронтовик': 1,
#  'случай': 5,
#  'сайт': 3,
#  'магнитка': 1,
#  'комар': 1,
#  'дитя': 33,
#  'оружие': 2,
#  'позиция': 1,
#  'класс': 2,
#  'билет': 1,
#  'автомобиль': 2,
#  'костика': 1,
#  'простонародье': 1,
#  'автограф': 1,
#  'наноинженер': 1,
#  'христос': 1,
#  'обитатель': 1,
#  'борис': 1,
#  'гороскоп': 2,
#  'волочков': 1,
#  'количество': 1,
#  'капитал': 2,
#  'сухофрукт': 1,
#  'война': 2,
#  'продукция': 2,
#  'знакомый': 1,
#  'борщ': 1,
#  'галерея': 1,
#  'математика': 1,
#  'пришелец': 1,
#  'защита': 1,
#  'претензия': 1,
#  'спортсмен': 1,
#  'футболист': 2,
#  'голос': 1,
#  'тишина': 1,
#  'тереза': 1,
#  'характер': 3,
#  'петрович': 1,
#  'экспозиция': 1,
#  'ромни': 1,
#  'писатель': 5,
#  'равновесие': 1,
#  'замечание': 1,
#  'старт': 2,
#  'накладка': 1,
#  'сознание': 1,
#  'байкал': 2,
#  'голованов': 1,
#  'ленин': 1,
#  'плечико': 1,
#  'янаев': 1,
#  'интернет': 2,
#  'графоман': 1,
#  'президент': 6,
#  'слух': 1,
#  'фотка': 1,
#  'сок': 1,
#  'пол': 2,
#  'яковлева': 1,
#  'запись': 1,
#  'сергей': 2,
#  'круг': 2,
#  'запад': 2,
#  'химия': 2,
#  'маннергейм': 1,
#  'прогулка': 1,
#  'воспитанник': 2,
#  'цивильск': 1,
#  'сюжетность': 1,
#  'женя': 1,
#  'первенец': 1,
#  'правительство': 4,
#  'тень': 1,
#  'дневник': 1,
#  'музей': 2,
#  'однокурсник': 1,
#  'гитлер': 1,
#  'фима': 1,
#  'пена': 1,
#  'передача': 1,
#  'исинбаев': 1,
#  'зрелище': 1,
#  'рыба': 3,
#  'работа': 18,
#  'актер': 6,
#  'андерс': 1,
#  'стихи-размышления': 1,
#  'маршрут': 1,
#  'бог': 4,
#  'лиля': 1,
#  'сыр': 1,
#  'толя': 1,
#  'летчик': 1,
#  'ад': 2,
#  'семья': 10,
#  'пугало': 1,
#  'оптимист': 3,
#  'сати': 1,
#  'стоунхендж': 1,
#  'автор': 1,
#  'ддт': 1,
#  'настроение': 2,
#  'мужчина': 11,
#  'восьмерка': 1,
#  'хаус': 1,
#  'звездочка': 1,
#  'кп': 1,
#  'боль': 1,
#  'монро': 1,
#  'стена': 2,
#  'собчак': 2,
#  'хозяйство': 2,
#  'владимирович': 1,
#  'менделеев': 1,
#  'партнер': 2,
#  'слой': 1,
#  'овес': 1,
#  'труба': 1,
#  'гипербореец': 1,
#  'студия': 1,
#  'лена': 1,
#  'историк': 1,
#  'яковлевна': 1,
#  'тетка': 1,
#  'адресат': 1,
#  'реал': 2,
#  'оглядка': 1,
#  'езуит': 1,
#  'сталин': 2,
#  'марк': 1,
#  'футбол': 9,
#  'финляндия': 2,
#  'рок': 2,
#  'внук': 2,
#  'иркутянин': 1,
#  'мистер': 1,
#  'экскурсия': 1,
#  'военком': 1,
#  'родина': 14,
#  'новость': 1,
#  'сибиряк': 1,
#  'нога': 5,
#  'широта': 1,
#  'пара': 1,
#  'дочь': 5,
#  'валерий': 1,
#  'регион': 1,
#  'возвращение': 2,
#  'юбилейный': 1,
#  'бар': 2,
#  'марковников': 1,
#  'златан': 1,
#  'возвышенность': 1,
#  'сентенция': 1,
#  'теснота': 1,
#  'житие': 1,
#  'балет': 1,
#  'кот': 4,
#  'карман': 2,
#  'роль': 8,
#  'ксан': 1,
#  'тренировка': 1,
#  'художник': 3,
#  'лето': 3,
#  'разработка': 1,
#  'семен': 1,
#  'кандидат': 2,
#  'пмс': 1,
#  'падение': 2,
#  'расстояние': 1,
#  'грузия': 2,
#  'спиннинг': 1,
#  'момент': 1,
#  'воздух': 1,
#  'персонаж': 3,
#  'вальдеррама': 1,
#  'маяк': 1,
#  'тип': 2,
#  'аркаим': 1,
#  'галочка': 1,
#  'мера': 5,
#  'животное': 4,
#  'мафиози': 1,
#  'беда': 3,
#  'хаос': 1,
#  'судьба': 3,
#  'шаман': 1,
#  'пресс-конференции': 1,
#  'карим': 1,
#  'вера': 5,
#  'беседа': 1,
#  'эксперимент': 2,
#  'телевизор': 1,
#  'ритм': 1,
#  'вячеслав': 1,
#  'ночь': 1,
#  'телевидение': 1,
#  'смородина': 2,
#  'строфа': 1,
#  'оправдание': 1,
#  'партнерство': 2,
#  'пикетчик': 1,
#  'оборона': 1,
#  'шаг': 2,
#  'екатерина': 1,
#  'руль': 1,
#  'приват-танцы': 1,
#  'нос': 1,
#  'дно': 1,
#  'требовательность': 1,
#  'резонанс': 1,
#  'сопредседатель': 2,
#  'термос': 1,
#  'пуэр': 2,
#  'общественность': 1,
#  'посул': 1,
#  'пресса': 4,
#  'джон': 1,
#  'киров': 1,
#  'подеста': 1,
#  'еврей': 1,
#  'китай': 2,
#  'мюнхен': 1,
#  'цветение': 1,
#  'патриотизм': 1,
#  'либерал': 1,
#  'экс-голкипер': 1,
#  'рената': 1,
#  'молоко': 1,
#  'родитель': 5,
#  'испания': 1,
#  'анита': 1,
#  'коррупция': 1,
#  'петр': 2,
#  'перец': 1,
#  'нетерпение': 1,
#  'зависимость': 1,
#  'возлюбленная': 1,
#  'молоток': 2,
#  'артур': 2,
#  'ресница': 1,
#  'текст': 1,
#  'гайсин': 1,
#  'понимание': 1,
#  'опера': 2,
#  'саночки': 2,
#  'платье': 1,
#  'антон': 2,
#  'юность': 1,
#  'фабио': 1,
#  'преподаватель': 3,
#  'строитель': 1,
#  'пространство': 2,
#  'мертвый': 1,
#  'блюдечко': 1,
#  'холод': 2,
#  'инициатива': 1,
#  'конструктор': 1,
#  'рахманинов': 1,
#  'видео': 1,
#  'иван': 3,
#  'константиновичах': 1,
#  'репетиция': 1,
#  'китаец': 2,
#  'общение': 2,
#  'грудь': 3,
#  'латвия': 1,
#  'пушкин': 4,
#  'ведро': 1,
#  'сновидец': 1,
#  'юбка': 1,
#  'кореец': 1,
#  'доверие': 1,
#  'плавник': 1,
#  'игрок': 2,
#  'подготовка': 1,
#  'терминатор': 1,
#  'эмоция': 1,
#  'георгий': 2,
#  'дата': 1,
#  'разум': 1,
#  'статуэтка': 1,
#  'чтение': 2,
#  'делегация': 1,
#  'стрелок': 1,
#  'деревня': 2,
#  'щедровицкий': 1,
#  'адрес': 2,
#  'классификация': 1,
#  'украина': 1,
#  'рай': 1,
#  'тепло': 1,
#  'рф': 2,
#  'майкл': 1,
#  'фраза': 1,
#  'массаж': 1,
#  'цикл': 1,
#  'картошка': 1,
#  'слон': 1,
#  'молодость': 2,
#  'водка': 1,
#  'смысл': 4,
#  'корица': 1,
#  'звук': 1,
#  'ханжество': 1,
#  'находка': 1,
#  'чемпион': 2,
#  'лаванда': 1,
#  'приживалка': 1,
#  'николай': 4,
#  'соус': 2,
#  'столяр': 1,
#  'огурец': 1,
#  'свекла': 1,
#  'театр': 9,
#  'нюша': 1,
#  'единомышленник': 1,
#  'фонд': 1,
#  'мадина': 1,
#  'россия': 22,
#  'брутальность': 2,
#  'окрошка': 1,
#  'саррот': 1,
#  'иркутск': 5,
#  'связь': 2,
#  'улочка': 1,
#  'мечта': 2,
#  'враг': 1,
#  'строка': 1,
#  'березка': 1,
#  'юлия': 1,
#  'комфорт': 1,
#  'пластичность': 1,
#  'хлеб': 2,
#  'опасность': 1,
#  'восторг': 3,
#  'расчет': 2,
#  'приятель': 1,
#  'степень': 1,
#  'базаревич': 1,
#  'недропользование': 1,
#  'пища': 1,
#  'член': 1,
#  'корт': 1,
#  'куратор': 1,
#  'предпочтение': 1,
#  'миллер': 1,
#  'молодежь': 1,
#  'народ': 13,
#  'реликвия': 1,
#  'вареник': 1,
#  'год': 28,
#  'техника': 2,
#  'душа': 7,
#  'бутылка': 1,
#  'погон': 1,
#  'александр': 5,
#  'спектр': 1,
#  'ненависть': 3,
#  'ветвь': 1,
#  'напиток': 1,
#  'спутник': 1,
#  'авария': 1,
#  'кредит': 1,
#  'вызов': 1,
#  'борисович': 1,
#  'тетя': 1,
#  'парламент': 1,
#  'питер': 1,
#  'физика': 2,
#  'хозяйка': 1,
#  'обман': 1,
#  'телепрограмма': 1,
#  'гайдай': 1,
#  'жилец': 2,
#  'разведчик': 1,
#  'лед': 2,
#  'усадьба': 1,
#  'крым': 1,
#  'фонтан': 1,
#  'басков': 2,
#  'власть': 14,
#  'политтехнология': 1,
#  'чудо': 3,
#  'астороном': 1,
#  'мода': 1,
#  'кран': 1,
#  'сынок': 2,
#  'обуза': 1,
#  'табуретка': 1,
#  'губернiя': 1,
#  'медведев': 2,
#  'размах': 1,
#  'егэ': 1,
#  'край': 1,
#  'положение': 1,
#  'помпилиус': 1,
#  'премьера': 1,
#  'лыжа': 2,
#  'воспитание': 1,
#  'поездка': 2,
#  'гибель': 1,
#  'чистота': 1,
#  'что-что': 1,
#  'вика': 1,
#  'кларнет': 1,
#  'случайность': 1,
#  'музыкант': 2,
#  'медик': 1,
#  'виталий': 1,
#  'слесарь': 1,
#  'надя': 1,
#  'ворота': 1,
#  'сезар': 1,
#  'переувлажнение': 1,
#  'приложение': 2,
#  'езда': 4,
#  'рома': 1,
#  'саша': 6,
#  'слеза': 1,
#  'анатолий': 2,
#  'фрик': 1,
#  'фотография': 4,
#  'кровать': 1,
#  'богиня': 1,
#  'сборная': 1,
#  'дача': 3,
#  'трюк': 1,
#  'песня': 7,
#  'цинизм': 1,
#  'глушаков': 1,
#  'иностранец': 3,
#  'транспорт': 1,
#  'дачник': 1,
#  'период': 1,
#  'джаз': 1,
#  'австралия': 1,
#  'режиссер': 7,
#  'тысяча': 1,
#  'победа': 2,
#  'чередование': 1,
#  'иммануил': 1,
#  'калорийна': 1,
#  'почва': 3,
#  'секрет': 1,
#  'оля': 1,
#  'гастроль': 2,
#  'право': 1,
#  'чудо-остров': 1,
#  'эйзенштейн': 1,
#  'палисадник': 1,
#  'околоноля': 1,
#  'сторона': 3,
#  'выставка': 2,
#  'качок': 1,
#  'благовещенск': 1,
#  'формат': 1,
#  'сант': 1,
#  'нквд': 1,
#  'валькирия': 1,
#  'гонка': 2,
#  'кота': 1,
#  'рецепция': 1,
#  'михайлович': 2,
#  'дорога': 2,
#  'площадь': 1,
#  'жюль': 1,
#  'четкость': 1,
#  'эрик': 1,
#  'маррей': 1,
#  'физкультура': 1,
#  'тарак': 1,
#  'сырость': 1,
#  'кожура': 1,
#  'чехонина': 1,
#  'помощь': 3,
#  'ласка': 1,
#  'россиянка': 1,
#  'рамка': 1,
#  'мясо': 2,
#  'привычка': 1,
#  'маша': 5,
#  'щедрость': 1,
#  'признание': 1,
#  'браунинг': 1,
#  'лас-вегасе': 1,
#  'лера': 1,
#  'трасса': 2,
#  'пластинка': 1,
#  'аналитик': 1,
#  'бесконтрольность': 1,
#  'создатель': 1,
#  'глубина': 1,
#  'ингредиент': 1,
#  'моцарт': 1,
#  'замужество': 1,
#  'энди': 2,
#  'условие': 1,
#  'мракобесие': 1,
#  'симонов': 1,
#  'хор': 1,
#  'прогноз': 1,
#  'наталья': 2,
#  'инструмент': 3,
#  'решение': 2,
#  'бой': 2,
#  'любовь': 10,
#  'шелехов': 1,
#  'обязан': 1,
#  'европа': 5,
#  'святой': 1,
#  'слово': 18,
#  'кисель': 1,
#  'квартира': 1,
#  'секс': 2,
#  'капуста': 1,
#  'цель': 2,
#  'путин': 6,
#  'комедия': 2,
#  '53а': 1,
#  'гаг': 1,
#  'величина': 1,
#  'слабость': 1,
#  'серьезность': 1,
#  'современник': 1,
#  'мозоль': 1,
#  'вождь': 2,
#  'сокольники': 2,
#  'песенка': 1,
#  'царь': 1,
#  'деятельность': 1,
#  'кавказ': 1,
#  'библиотека': 1,
#  'уста': 1,
#  'лукавство': 1,
#  'труд': 2,
#  'новинка': 1,
#  'изделие': 1,
#  'письмо': 2,
#  'экология': 1,
#  'спектакль': 3,
#  'место': 12,
#  'состояние': 4,
#  'цветочек': 1,
#  'троицкая': 1,
#  'сотникова': 1,
#  'машка': 1,
#  'регистрация': 1,
#  'часть': 1,
#  'цех': 1,
#  'карлос': 1,
#  'фиби': 1,
#  'каролин': 1,
#  'лонгория': 1,
#  'широков': 1,
#  'титовка': 1,
#  'гений': 1,
#  'ожесточение': 1,
#  'вциом': 1,
#  'совет': 4,
#  'игра': 8,
#  'константин': 4,
#  'опьянение': 1,
#  'павел': 1,
#  'папой-королем': 1,
#  'балл': 1,
#  'публика': 5,
#  'кличка': 1,
#  'гардероб': 1,
#  'благотворитель': 1,
#  'сад': 2,
#  'охота': 4,
#  'иванович': 1,
#  'мандарин': 1,
#  'челси': 1,
#  'кара': 1,
#  'нелидов': 1,
#  'государство': 2,
#  'призыв': 1,
#  'предмет': 5,
#  'газон': 1,
#  'трубка': 2,
#  'умножение': 1,
#  'приказ': 1,
#  'уваров': 1,
#  'афиша': 1,
#  'поклонник': 3,
#  'брюнет': 1,
#  'причина': 5,
#  'произведение': 2,
#  'менеджер': 2,
#  'апостол': 1,
#  'кетут': 1,
#  'открытка': 1,
#  'анатольевна': 1,
#  'граница': 2,
#  'гитара': 2,
#  'уверенность': 1,
#  'наставник': 1,
#  'евгений': 1,
#  'гостья': 1,
#  'татьяна': 2,
#  'андрей': 7,
#  'германика': 1,
#  'сюжет': 2,
#  'бютор': 1,
#  'солнцев': 1,
#  'бирюс': 1,
#  'греция': 1,
#  'ростропович': 1,
#  'барто': 1,
#  'збышек': 1,
#  'чарльстон': 1,
#  'почта': 1,
#  'рана': 1,
#  'образование': 1,
#  'корма': 1,
#  'лесенка': 1,
#  'турция': 1,
#  'кинопанорама': 1,
#  'ребята': 6,
#  'дед': 2,
#  'беспорядочность': 1,
#  'фетисов': 1,
#  'михайловна': 3,
#  'рита': 1,
#  'хранитель': 1,
#  'блюдо': 5,
#  'толкователь': 1,
#  'выразительность': 1,
#  'линия': 1,
#  'боря': 1,
#  'чайковский': 4,
#  'катя': 2,
#  'возможность': 5,
#  'масуд': 1,
#  'воробьев': 1,
#  'разносол': 1,
#  'глист': 1,
#  'преступник': 1,
#  'составитель': 1,
#  'реактор': 1,
#  'собака': 1,
#  'медведь': 1,
#  'подруга': 2,
#  'дух': 2,
#  'подмосковье': 1,
#  'оладья': 1,
#  'барыня': 1,
#  'облик': 1,
#  'свет': 4,
#  'баня': 2,
#  'общительность': 1,
#  'январь': 1,
#  'неграмотность': 1,
#  'психоделик': 1,
#  'полмиллион': 1,
#  'васин': 1,
#  'обухова': 1,
#  'достижение': 1,
#  'выражение': 3,
#  'сила': 4,
#  'брошюра': 1,
#  'гаск': 1,
#  'анюков': 1,
#  'балашов': 1,
#  'аллен': 1,
#  'современность': 1,
#  'неглижа': 1,
#  'бойфренд': 1,
#  'заведение': 2,
#  'маркс': 1,
#  'школа': 7,
#  'тонкость': 1,
#  'лиза': 1,
#  'кондопог': 1,
#  'марина': 1,
#  'жалейка': 1,
#  'пятиэтажка': 1,
#  'больница': 1,
#  'иней': 2,
#  'буква': 2,
#  'документ': 1,
#  'статус': 1,
#  'ключ': 1,
#  'бред': 1,
#  'flashforward': 1,
#  'логика': 1,
#  'мануйлов': 1,
#  'фрэсис': 1,
#  'справедливость': 1,
#  'открытие': 1,
#  'область': 3,
#  'михайловка': 1,
#  'шанхайка': 1,
#  'распутина': 1,
#  'юрлов': 1,
#  'любимая': 1,
#  'нервозность': 1,
#  'цветик-семицветик': 1,
#  'покер': 2,
#  'насмешка': 1,
#  'костюм': 1,
#  'кухня': 6,
#  'арсентий': 1,
#  'героиня': 2,
#  'система': 2,
#  'comedy': 2,
#  'специальность': 1,
#  'пьеса': 1,
#  'счастье': 1,
#  'курс': 2,
#  'лида': 1,
#  'перерыв': 1,
#  'сочетание': 2,
#  'пэтти': 1,
#  'следователь': 2,
#  'чувство': 2,
#  'неделя': 1,
#  'динамо': 1,
#  'север': 1,
#  'андерссон': 1,
#  'перевод': 1,
#  'объектив': 1,
#  'лошадь': 2,
#  'неказистость': 1,
#  'сибирь': 2,
#  'неудобство': 1,
#  'онищенко': 1,
#  'поворот': 1,
#  'середина': 1,
#  'мсб': 1,
#  'коммунист': 3,
#  'железа': 1,
#  'пьерис': 1,
#  'евтушенков': 1,
#  'данные': 2,
#  'моча': 1,
#  'горожанин': 3,
#  'перспектива': 3,
#  'муза': 1,
#  'васильевич': 2,
#  'овсянка': 2,
#  'мать': 7,
#  'американец': 1,
#  'петербург': 1,
#  'нася': 1,
#  'номер': 1,
#  'иоселиани': 1,
#  'капелька': 1,
#  'виолончель': 1,
#  'уроженец': 1,
#  'банкир': 1,
#  'барышня': 1,
#  'событие': 1,
#  'головоломка': 1,
#  'адам': 1,
#  'список': 3,
#  'склад': 2,
#  'кинотеатр': 1,
#  'клюшка': 1,
#  'поле': 1,
#  'программа': 4,
#  'чай': 1,
#  'ребятишки': 1,
#  'искоростенский': 1,
#  'иллюстрация': 2,
#  'карен': 1,
#  'чувашия': 1,
#  'горесть': 1,
#  'краевед': 1,
#  'станция': 1,
#  'карина': 1,
#  'обсуждение': 1,
#  'игрушка': 3,
#  'пола': 1,
#  'леви': 1,
#  'артем': 2,
#  'фантазер': 1,
#  'отделение': 1,
#  'карьера': 3,
#  'угол': 1,
#  'плод': 2,
#  'папа': 8,
#  'кант': 1,
#  'омск': 1,
#  'тайга': 3,
#  'приживалок': 1,
#  'контекст': 1,
#  'тартар': 1,
#  'блок': 2,
#  'великобритания': 1,
#  'бах': 1,
#  'деталь': 3,
#  'снасть': 1,
#  'фекла': 1,
#  'академик': 1,
#  'вставка': 1,
#  'петровна': 1,
#  'срок': 2,
#  'саморазрушение': 1,
#  'истина': 1,
#  'контрабас': 1,
#  'отличие': 3,
#  'принцип': 3,
#  'архив': 1,
#  'вестминстер': 1,
#  'стругацкий': 1,
#  'турист': 2,
#  'лозунг': 1,
#  'баталов': 1,
#  'коллектив': 1,
#  'запах': 1,
#  'романс': 1,
#  'быт': 1,
#  'лекция': 1,
#  'общее': 1,
#  'тон': 1,
#  'палец': 1,
#  'анна-кайса': 1,
#  'здоровье': 1,
#  'хит': 2,
#  'посетитель': 1,
#  'психолог': 1,
#  'балалайка': 1,
#  'пес': 1,
#  'клиентка': 1,
#  'удовольствие': 6,
#  'самолет': 1,
#  'композитор': 2,
#  'статья': 4,
#  'хоккей': 5,
#  'россиянин': 4,
#  'музыка': 9,
#  'останкино': 1,
#  'понят': 1,
#  'анекдот': 1,
#  'евровидение': 1,
#  'друг': 15,
#  'закон': 2,
#  ...}

# %%
cases
# Out:
# {'a': 806, 'd': 149, 'g': 827, 'i': 258, 'l': 291, 'n': 1170, 'v': 1}

# %%
# import os
# for doc in os.listdir(".\corpora"):
#     doc = pd.read_csv(".\corpora\\" + doc,delimiter='\t',header=0,encoding='utf-8')
#     (preps, nouns, cases) = prepfinder('заменить', doc, 'prep+nouns.csv')
# Out:
# Extraction time: 7.2140048265457155
# Extraction time: 7.250344371795654
# Extraction time: 7.289626948038737
# Extraction time: 8.039333148797352

# %%
document.head(50)
# Out:
#     sent_id  word_num        token        lemma POS        gramm  head  \
# 0         1         1          Мне            я   P      P-1-sdn     4
# 1         1         2     отчаянно     отчаянно   R            R     4
# 2         1         3           не           не   Q            Q     4
# 3         1         4      хватает      хватать   V   Vmip3s-a-e     0
# 4         1         5    романтики    романтика   N       Ncfsgn     4
# 5         1         6            и            и   C            C     5
# 6         1         7         веры         вера   N       Ncfsgn     6
# 7         1         8            ,            ,   ,            ,     7
# 8         1         9            я            я   P      P-1-snn    10
# 9         1        10    задыхаюсь   задыхаться   V   Vmip1s-m-e     4
# 10        1        11            ,            ,   ,            ,    10
# 11        1        12          как          как   C            C    10
# 12        1        13         рыба         рыба   N       Ncfsny    12
# 13        1        14            ,            ,   ,            ,    13
# 14        1        15  выброшенная    выбросить   V  Vmps-sfpfpn    10
# 15        1        16           на           на   S         Sp-a    15
# 16        1        17        берег        берег   N       Ncmsan    16
# 17        1        18            .            .   S         SENT    17
# 18        2         1         Пора         пора   R            R     0
# 19        2         2            ,            ,   ,            ,     1
# 20        2         3      наконец      наконец   R            R     1
# 21        2         4            ,            ,   ,            ,     3
# 22        2         5  успокоиться  успокоиться   V   Vmn----m-p     1
# 23        2         6            ,            ,   ,            ,     5
# 24        2         7     перестав    перестать   V   Vmgs---a-p     1
# 25        2         8       делить       делить   V   Vmn----a-e     7
# 26        2         9           не           не   Q            Q    10
# 27        2        10       только       только   Q            Q    11
# 28        2        11        людей      человек   N       Ncmpay     8
# 29        2        12            ,            ,   ,            ,    11
# 30        2        13           но           но   C            C     7
# 31        2        14            и            и   C            C    13
# 32        2        15        целые        целый   A      Afpmpnf    16
# 33        2        16    поколения    поколение   N       Ncnpnn    13
# 34        2        17           на           на   S         Sp-l     7
# 35        2        18           \t            -   -           17  PUNC
# 36        2        19        своих         свой   P      P---pla     0
# 37        2        20           \t            -   -           19  PUNC
# 38        2        21            и            и   C            C    19
# 39        2        22           \t            -   -           21  PUNC
# 40        2        23        чужих        чужой   A      Afpmpgf    21
# 41        2        24           \t            -   -           23  PUNC
# 42        2        25            .            .   S         SENT    23
# 43        3         1           26           26   M       Mc---d     5
# 44        3         2       января       январь   N       Ncmsgn     1
# 45        3         3         2010         2010   M       Mc---d     4
# 46        3         4         года          год   N       Ncmsgn     2
# 47        3         5        около        около   S         Sp-g     0
# 48        3         6       девяти       девять   M        Mc--g     7
# 49        3         7        часов         часы   N       Ncmpgn     5
#
#            link
# 0       2-компл
# 1          обст
# 2       огранич
# 3          ROOT
# 4        предик
# 5         сочин
# 6     соч-союзн
# 7          PUNC
# 8        предик
# 9      сент-соч
# 10         PUNC
# 11      сравнит
# 12  сравн-союзн
# 13         PUNC
# 14        сочин
# 15      2-компл
# 16        предл
# 17         PUNC
# 18         ROOT
# 19         PUNC
# 20        вводн
# 21         PUNC
# 22       предик
# 23         PUNC
# 24         обст
# 25      1-компл
# 26      огранич
# 27      огранич
# 28      1-компл
# 29         PUNC
# 30        сочин
# 31      огранич
# 32        опред
# 33    соч-союзн
# 34         обст
# 35          NaN
# 36         ROOT
# 37          NaN
# 38        сочин
# 39          NaN
# 40    соч-союзн
# 41          NaN
# 42         PUNC
# 43         обст
# 44        атриб
# 45        опред
# 46        атриб
# 47         ROOT
# 48     количест
# 49        предл
